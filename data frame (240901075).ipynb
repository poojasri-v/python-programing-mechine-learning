# %%
import pandas as pd
import numpy as np
df=pd.DataFrame(np.random.randn(4,3), index=['a','c','d','f'],
 columns=['one','two','three'])
df = df.reindex(['a','b','c','d','e','f'])
print("Original Dataframe with NaN\n",df)
print("\n")
print("Dropped DataFrame\n",df.dropna())
print("\n")
# Out:
# Original Dataframe with NaN
#          one       two     three
# a  1.107715  0.846741 -1.250634
# b       NaN       NaN       NaN
# c -0.178038 -1.099921 -0.169210
# d  0.362863  0.700928 -0.106510
# e       NaN       NaN       NaN
# f  0.273716  2.640948  1.213559
#
#
# Dropped DataFrame
#          one       two     three
# a  1.107715  0.846741 -1.250634
# c -0.178038 -1.099921 -0.169210
# d  0.362863  0.700928 -0.106510
# f  0.273716  2.640948  1.213559

# %%
df=pd.DataFrame(np.random.randn(4,3), index=['a','c','d','f'],
 columns=['one','two','three'])
df = df.reindex(['a','b','c'])
print("Original Dataframe:\n",df)
print("\n")
print("NaN replaced with '0':\n")
print(df.fillna(0))
# Out:
# Original Dataframe:
#          one       two     three
# a  0.525584  1.063659  0.073632
# b       NaN       NaN       NaN
# c -0.084883  0.189983  2.512687
#
#
# NaN replaced with '0':
#
#         one       two     three
# a  0.525584  1.063659  0.073632
# b  0.000000  0.000000  0.000000
# c -0.084883  0.189983  2.512687

# %%
df=pd.DataFrame({'one':[10,20,80,40,50],
 'two':[60,70,80,0,10]})
print("Original Dataframe:\n",df)
print("\n DataFrame with replaced values:\n")
print(df.replace({10:5,80:3}))
# Out:
# Original Dataframe:
#     one  two
# 0   10   60
# 1   20   70
# 2   80   80
# 3   40    0
# 4   50   10
#
#  DataFrame with replaced values:
#
#    one  two
# 0    5   60
# 1   20   70
# 2    3    3
# 3   40    0
# 4   50    5

# %%
df=pd.DataFrame(np.random.randn(4,3), index=['a','c','d','f'],
 columns=['one','two','three'])
df = df.reindex(['a','b','c','d','e','f'])
print("Original Dataframe:\n",df)
print("\nNan-with True fill:\n")
print(df['one'].isnull())
# Out:
# Original Dataframe:
#          one       two     three
# a  1.527516 -0.303172  0.110729
# b       NaN       NaN       NaN
# c  0.610389  1.794661 -0.195308
# d -1.245282 -1.593888 -0.408259
# e       NaN       NaN       NaN
# f -0.720784 -0.997212  1.071794
#
# Nan-with True fill:
#
# a    False
# b     True
# c    False
# d    False
# e     True
# f    False
# Name: one, dtype: bool

# %%
df=pd.DataFrame(np.random.randn(4,3), index=['a','c','d','f'],
 columns=['one','two','three'])
df = df.reindex(['a','b','c','d','e','f'])
print("Original Dataframe:\n",df)
print("\nNaN - Filled with Background values:\n")
print(df.fillna(method='bfill'))
# Out:
# Original Dataframe:
#          one       two     three
# a -1.970330 -0.946506 -0.712209
# b       NaN       NaN       NaN
# c  1.682808  0.547368  0.119652
# d -1.106138  0.778196 -0.905150
# e       NaN       NaN       NaN
# f  0.719897  0.661328  1.714308
#
# NaN - Filled with Background values:
#
#         one       two     three
# a -1.970330 -0.946506 -0.712209
# b  1.682808  0.547368  0.119652
# c  1.682808  0.547368  0.119652
# d -1.106138  0.778196 -0.905150
# e  0.719897  0.661328  1.714308
# f  0.719897  0.661328  1.714308
